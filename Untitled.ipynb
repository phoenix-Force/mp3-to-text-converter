# %%
from pydub import AudioSegment 
import speech_recognition as sr 
  
# Input audio file to be sliced 
audio = AudioSegment.from_wav("a007.wav")

# %%
n = len(audio)
n
# Out:
# 1639758

# %%
fh = open("project_2_007.txt", "w+")

# %%
interval = 12 * 1000
overlap = 1.5 * 1000
start = 0
end = 0
flag = 0
counter = 0

# %%
for i in range(0, 2 * n, interval): 
    if i == 0: 
        start = 0
        end = interval 
    else: 
        start = end - overlap 
        end = start + interval  
    if end >= n:
        end = n 
        flag = 1
    chunk = audio[start:end] 
    filename = 'chunk'+str(counter)+'.wav'
    chunk.export(filename, format ="wav") 
    print("Processing chunk "+str(counter)+". Start = "+str(start)+" end = "+str(end)) 
    counter = counter + 1
    AUDIO_FILE = filename 
    r = sr.Recognizer() 
    with sr.AudioFile(AUDIO_FILE) as source: 
        audio_listened = r.listen(source) 
    try:     
        rec = r.recognize_google(audio_listened) 
        fh.write(rec+" ") 
    except sr.UnknownValueError: 
        print("Could not understand audio") 
    except sr.RequestError as e: 
        print("Could not request results.") 
    if flag == 1: 
        fh.close() 
        break
# Out:
# Processing chunk 0. Start = 0 end = 12000
# Could not understand audio
# Processing chunk 1. Start = 10500.0 end = 22500.0
# Could not understand audio
# Processing chunk 2. Start = 21000.0 end = 33000.0
# Processing chunk 3. Start = 31500.0 end = 43500.0
# Processing chunk 4. Start = 42000.0 end = 54000.0
# Processing chunk 5. Start = 52500.0 end = 64500.0
# Processing chunk 6. Start = 63000.0 end = 75000.0
# Processing chunk 7. Start = 73500.0 end = 85500.0
# Processing chunk 8. Start = 84000.0 end = 96000.0
# Could not request results.
# Processing chunk 9. Start = 94500.0 end = 106500.0
# Processing chunk 10. Start = 105000.0 end = 117000.0
# Processing chunk 11. Start = 115500.0 end = 127500.0
# Processing chunk 12. Start = 126000.0 end = 138000.0
# Processing chunk 13. Start = 136500.0 end = 148500.0
# Processing chunk 14. Start = 147000.0 end = 159000.0
# Processing chunk 15. Start = 157500.0 end = 169500.0
# Processing chunk 16. Start = 168000.0 end = 180000.0
# Processing chunk 17. Start = 178500.0 end = 190500.0
# Processing chunk 18. Start = 189000.0 end = 201000.0
# Processing chunk 19. Start = 199500.0 end = 211500.0
# Processing chunk 20. Start = 210000.0 end = 222000.0
# Processing chunk 21. Start = 220500.0 end = 232500.0
# Processing chunk 22. Start = 231000.0 end = 243000.0
# Processing chunk 23. Start = 241500.0 end = 253500.0
# Processing chunk 24. Start = 252000.0 end = 264000.0
# Processing chunk 25. Start = 262500.0 end = 274500.0
# Processing chunk 26. Start = 273000.0 end = 285000.0
# Processing chunk 27. Start = 283500.0 end = 295500.0
# Processing chunk 28. Start = 294000.0 end = 306000.0
# Processing chunk 29. Start = 304500.0 end = 316500.0
# Processing chunk 30. Start = 315000.0 end = 327000.0
# Processing chunk 31. Start = 325500.0 end = 337500.0
# Processing chunk 32. Start = 336000.0 end = 348000.0
# Processing chunk 33. Start = 346500.0 end = 358500.0
# Processing chunk 34. Start = 357000.0 end = 369000.0
# Processing chunk 35. Start = 367500.0 end = 379500.0
# Processing chunk 36. Start = 378000.0 end = 390000.0
# Processing chunk 37. Start = 388500.0 end = 400500.0
# Processing chunk 38. Start = 399000.0 end = 411000.0
# Processing chunk 39. Start = 409500.0 end = 421500.0
# Processing chunk 40. Start = 420000.0 end = 432000.0
# Processing chunk 41. Start = 430500.0 end = 442500.0
# Processing chunk 42. Start = 441000.0 end = 453000.0
# Processing chunk 43. Start = 451500.0 end = 463500.0
# Processing chunk 44. Start = 462000.0 end = 474000.0
# Processing chunk 45. Start = 472500.0 end = 484500.0
# Processing chunk 46. Start = 483000.0 end = 495000.0
# Processing chunk 47. Start = 493500.0 end = 505500.0
# Processing chunk 48. Start = 504000.0 end = 516000.0
# Processing chunk 49. Start = 514500.0 end = 526500.0
# Processing chunk 50. Start = 525000.0 end = 537000.0
# Processing chunk 51. Start = 535500.0 end = 547500.0
# Processing chunk 52. Start = 546000.0 end = 558000.0
# Processing chunk 53. Start = 556500.0 end = 568500.0
# Processing chunk 54. Start = 567000.0 end = 579000.0
# Processing chunk 55. Start = 577500.0 end = 589500.0
# Processing chunk 56. Start = 588000.0 end = 600000.0
# Processing chunk 57. Start = 598500.0 end = 610500.0
# Processing chunk 58. Start = 609000.0 end = 621000.0
# Processing chunk 59. Start = 619500.0 end = 631500.0
# Processing chunk 60. Start = 630000.0 end = 642000.0
# Processing chunk 61. Start = 640500.0 end = 652500.0
# Processing chunk 62. Start = 651000.0 end = 663000.0
# Processing chunk 63. Start = 661500.0 end = 673500.0
# Processing chunk 64. Start = 672000.0 end = 684000.0
# Processing chunk 65. Start = 682500.0 end = 694500.0
# Processing chunk 66. Start = 693000.0 end = 705000.0
# Processing chunk 67. Start = 703500.0 end = 715500.0
# Processing chunk 68. Start = 714000.0 end = 726000.0
# Processing chunk 69. Start = 724500.0 end = 736500.0
# Processing chunk 70. Start = 735000.0 end = 747000.0
# Processing chunk 71. Start = 745500.0 end = 757500.0
# Processing chunk 72. Start = 756000.0 end = 768000.0
# Processing chunk 73. Start = 766500.0 end = 778500.0
# Processing chunk 74. Start = 777000.0 end = 789000.0
# Processing chunk 75. Start = 787500.0 end = 799500.0
# Processing chunk 76. Start = 798000.0 end = 810000.0
# Processing chunk 77. Start = 808500.0 end = 820500.0
# Processing chunk 78. Start = 819000.0 end = 831000.0
# Processing chunk 79. Start = 829500.0 end = 841500.0
# Processing chunk 80. Start = 840000.0 end = 852000.0
# Processing chunk 81. Start = 850500.0 end = 862500.0
# Processing chunk 82. Start = 861000.0 end = 873000.0
# Processing chunk 83. Start = 871500.0 end = 883500.0
# Processing chunk 84. Start = 882000.0 end = 894000.0
# Processing chunk 85. Start = 892500.0 end = 904500.0
# Processing chunk 86. Start = 903000.0 end = 915000.0
# Processing chunk 87. Start = 913500.0 end = 925500.0
# Processing chunk 88. Start = 924000.0 end = 936000.0
# Processing chunk 89. Start = 934500.0 end = 946500.0
# Processing chunk 90. Start = 945000.0 end = 957000.0
# Processing chunk 91. Start = 955500.0 end = 967500.0
# Processing chunk 92. Start = 966000.0 end = 978000.0
# Processing chunk 93. Start = 976500.0 end = 988500.0
# Processing chunk 94. Start = 987000.0 end = 999000.0
# Processing chunk 95. Start = 997500.0 end = 1009500.0
# Processing chunk 96. Start = 1008000.0 end = 1020000.0
# Processing chunk 97. Start = 1018500.0 end = 1030500.0
# Processing chunk 98. Start = 1029000.0 end = 1041000.0
# Processing chunk 99. Start = 1039500.0 end = 1051500.0
# Processing chunk 100. Start = 1050000.0 end = 1062000.0
# Processing chunk 101. Start = 1060500.0 end = 1072500.0
# Processing chunk 102. Start = 1071000.0 end = 1083000.0
# Processing chunk 103. Start = 1081500.0 end = 1093500.0
# Processing chunk 104. Start = 1092000.0 end = 1104000.0
# Processing chunk 105. Start = 1102500.0 end = 1114500.0
# Processing chunk 106. Start = 1113000.0 end = 1125000.0
# Processing chunk 107. Start = 1123500.0 end = 1135500.0
# Processing chunk 108. Start = 1134000.0 end = 1146000.0
# Processing chunk 109. Start = 1144500.0 end = 1156500.0
# Processing chunk 110. Start = 1155000.0 end = 1167000.0
# Processing chunk 111. Start = 1165500.0 end = 1177500.0
# Processing chunk 112. Start = 1176000.0 end = 1188000.0
# Processing chunk 113. Start = 1186500.0 end = 1198500.0
# Processing chunk 114. Start = 1197000.0 end = 1209000.0
# Processing chunk 115. Start = 1207500.0 end = 1219500.0
# Processing chunk 116. Start = 1218000.0 end = 1230000.0
# Processing chunk 117. Start = 1228500.0 end = 1240500.0
# Processing chunk 118. Start = 1239000.0 end = 1251000.0
# Processing chunk 119. Start = 1249500.0 end = 1261500.0
# Processing chunk 120. Start = 1260000.0 end = 1272000.0
# Processing chunk 121. Start = 1270500.0 end = 1282500.0
# Processing chunk 122. Start = 1281000.0 end = 1293000.0
# Processing chunk 123. Start = 1291500.0 end = 1303500.0
# Processing chunk 124. Start = 1302000.0 end = 1314000.0
# Processing chunk 125. Start = 1312500.0 end = 1324500.0
# Processing chunk 126. Start = 1323000.0 end = 1335000.0
# Processing chunk 127. Start = 1333500.0 end = 1345500.0
# Processing chunk 128. Start = 1344000.0 end = 1356000.0
# Processing chunk 129. Start = 1354500.0 end = 1366500.0
# Processing chunk 130. Start = 1365000.0 end = 1377000.0
# Processing chunk 131. Start = 1375500.0 end = 1387500.0
# Processing chunk 132. Start = 1386000.0 end = 1398000.0
# Processing chunk 133. Start = 1396500.0 end = 1408500.0
# Processing chunk 134. Start = 1407000.0 end = 1419000.0
# Processing chunk 135. Start = 1417500.0 end = 1429500.0
# Processing chunk 136. Start = 1428000.0 end = 1440000.0
# Processing chunk 137. Start = 1438500.0 end = 1450500.0
# Processing chunk 138. Start = 1449000.0 end = 1461000.0
# Processing chunk 139. Start = 1459500.0 end = 1471500.0
# Processing chunk 140. Start = 1470000.0 end = 1482000.0
# Processing chunk 141. Start = 1480500.0 end = 1492500.0
# Processing chunk 142. Start = 1491000.0 end = 1503000.0
# Processing chunk 143. Start = 1501500.0 end = 1513500.0
# Processing chunk 144. Start = 1512000.0 end = 1524000.0
# Processing chunk 145. Start = 1522500.0 end = 1534500.0
# Processing chunk 146. Start = 1533000.0 end = 1545000.0
# Processing chunk 147. Start = 1543500.0 end = 1555500.0
# Processing chunk 148. Start = 1554000.0 end = 1566000.0
# Processing chunk 149. Start = 1564500.0 end = 1576500.0
# Processing chunk 150. Start = 1575000.0 end = 1587000.0
# Processing chunk 151. Start = 1585500.0 end = 1597500.0
# Processing chunk 152. Start = 1596000.0 end = 1608000.0
# Processing chunk 153. Start = 1606500.0 end = 1618500.0
# Could not understand audio
# Processing chunk 154. Start = 1617000.0 end = 1629000.0
# Could not understand audio
# Processing chunk 155. Start = 1627500.0 end = 1639500.0
# Could not understand audio
# Processing chunk 156. Start = 1638000.0 end = 1639758
# Could not understand audio
